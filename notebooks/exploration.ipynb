# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Charger le dataset
df = pd.read_csv('../data/ipynb_checkpoints/Mental Health Classification.csv')
df.columns = df.columns.str.strip().str.replace('\xa0',' ', regex=True)
[col for col in df.columns if "depress" in col.lower()]

df.head()
# Out:
#    Gender  Age  Education_Level  Employment_Status  Depression_Type  Symptoms  \
# 0       1   25                2                  3                5        11
# 1       1   25                2                  2                5         0
# 2       1   25                2                  3                2         5
# 3       0   25                2                  2                6         7
# 4       1   25                2                  2                6         5
#
#    Low_Energy  Low_SelfEsteem  Search_Depression_Online  Worsening_Depression  \
# 0           1               1                         1                     1
# 1           1               1                         0                     1
# 2           1               1                         1                     1
# 3           0               1                         0                     1
# 4           0               0                         0                     0
#
# ...

# %%
# Dimensions du dataset
print("Dimensions :", df.shape)
df.info()
# Out:
# Dimensions : (1998, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1998 entries, 0 to 1997
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Gender                    1998 non-null   int64
#  1   Age                       1998 non-null   int64
#  2   Education_Level           1998 non-null   int64
#  3   Employment_Status         1998 non-null   int64
#  4   Depression_Type           1998 non-null   int64
#  5   Symptoms                  1998 non-null   int64
#  6   Low_Energy                1998 non-null   int64
#  7   Low_SelfEsteem            1998 non-null   int64
#  8   Search_Depression_Online  1998 non-null   int64
#  9   Worsening_Depression      1998 non-null   int64
#  10  Your overeating level     1998 non-null   int64
#  11  How many times you eat    1998 non-null   int64
#  12  SocialMedia_Hours         1998 non-null   int64
# ...

# %%
# Statistiques descriptives
df.describe(include='all')
# Out:
#             Gender          Age  Education_Level  Employment_Status  \
# count  1998.000000  1998.000000      1998.000000        1998.000000
# mean      0.514014    24.261762         1.869369           2.097097
# std       0.499929     7.928578         0.472003           0.873915
# min       0.000000    10.000000         0.000000           0.000000
# 25%       0.000000    25.000000         2.000000           2.000000
# 50%       1.000000    25.000000         2.000000           2.000000
# 75%       1.000000    25.000000         2.000000           2.000000
# max       1.000000    35.000000         3.000000           4.000000
#
#        Depression_Type     Symptoms   Low_Energy  Low_SelfEsteem  \
# count      1998.000000  1998.000000  1998.000000     1998.000000
# mean          5.673173     6.553053     0.709710        0.696196
# std           2.935595     3.852428     0.485973        0.488522
# min           0.000000     0.000000     0.000000        0.000000
# ...

# %%
# Statistiques descriptives
df.describe(include='all')
# Out:
#             Gender          Age  Education_Level  Employment_Status  \
# count  1998.000000  1998.000000      1998.000000        1998.000000
# mean      0.514014    24.261762         1.869369           2.097097
# std       0.499929     7.928578         0.472003           0.873915
# min       0.000000    10.000000         0.000000           0.000000
# 25%       0.000000    25.000000         2.000000           2.000000
# 50%       1.000000    25.000000         2.000000           2.000000
# 75%       1.000000    25.000000         2.000000           2.000000
# max       1.000000    35.000000         3.000000           4.000000
#
#        Depression_Type     Symptoms   Low_Energy  Low_SelfEsteem  \
# count      1998.000000  1998.000000  1998.000000     1998.000000
# mean          5.673173     6.553053     0.709710        0.696196
# std           2.935595     3.852428     0.485973        0.488522
# min           0.000000     0.000000     0.000000        0.000000
# ...

# %%
df['Suicide_Attempts'].value_counts()
# Si déséquilibré → utiliser SMOTE
# Out:
# Suicide_Attempts
# 0    559
# 1    495
# 3    483
# 2    461
# Name: count, dtype: int64

# %%
print(df.columns.tolist())

plt.figure(figsize=(12,6))
sns.heatmap(df.select_dtypes(include=['int64','float64']).corr(), annot=True)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ['Gender', 'Age', 'Education_Level', 'Employment_Status', 'Depression_Type', 'Symptoms', 'Low_Energy', 'Low_SelfEsteem', 'Search_Depression_Online', 'Worsening_Depression', 'Your overeating level', 'How many times you eat', 'SocialMedia_Hours', 'SocialMedia_WhileEating', 'Sleep_Hours', 'Nervous_Level', 'Depression_Score', 'Coping_Methods', 'Self_Harm', 'Mental_Health_Support', 'Suicide_Attempts']

# %%
plt.figure()
df['Depression_Type'].value_counts().plot(kind='bar')
plt.title('Distribution du type de dépression')
plt.xlabel('Type')
plt.ylabel('Nombre')
plt.show()
